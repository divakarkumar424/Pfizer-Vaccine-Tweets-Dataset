# %% [markdown]
# # Pfizer Vaccine💉 Tweets

# %% [markdown]
# <img src="Pfizer Vaccine Tweets.jpg"/>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import warnings
warnings.simplefilter("ignore")

# %%
data = pd.read_csv(r"C:\Users\PC-1\Desktop\nano\Data Analytics\Data\archive_3\vaccination_tweets.csv")

# %%
data
# Out:
#                        id              user_name              user_location  \
# 0     1340539111971516416             Rachel Roh  La Crescenta-Montrose, CA
# 1     1338158543359250433            Albert Fong          San Francisco, CA
# 2     1337858199140118533               eli🇱🇹🇪🇺👌                   Your Bed
# 3     1337855739918835717          Charles Adler     Vancouver, BC - Canada
# 4     1337854064604966912   Citizen News Channel                        NaN
# ...                   ...                    ...                        ...
# 4641  1351502293213057025            Riikka Kevo        .fi .fr .se .uk .de
# 4642  1351500433727098880         SUR in English              Malaga, Spain
# 4643  1351492894087999489   Sleepy Hollow Addict                    Seattle
# 4644  1351492220558442497  Edenbridge Healthcare         Wakefield, England
# 4645  1351488680846893057         Ian 3.5% #FBPE                Cornwall UK
#
#                                        user_description         user_created  \
# 0     Aggregator of Asian American news; scanning di...  2009-04-08 17:52:46
# 1     Marketing dude, tech geek, heavy metal & '80s ...  2009-09-21 15:27:30
# 2                                        heil, hydra 🖐☺  2020-06-25 23:30:28
# 3     Hosting "CharlesAdlerTonight" Global News Radi...  2008-09-10 11:28:53
# 4     Citizen News Channel bringing you an alternati...  2020-04-23 17:58:42
# ...                                                 ...                  ...
# 4641  The Future is Here. #Covid19 #FineArt #GeoPoli...  2017-02-19 13:09:04
# 4642  SUR in English, the English-language newspaper...  2012-10-09 12:42:00
# 4643  ♥Sleepy Hollow Addicts- a Sleepyhead obsessed ...  2013-12-01 04:44:50
# 4644  Edenbridge Healthcare provide an award-winning...  2014-03-06 00:00:27
# 4645  Detest this Gov! No DM's! #RejoinEU, hate Brex...  2011-07-18 12:54:18
#
#       user_followers  user_friends  user_favourites  user_verified  \
# 0                405          1692             3247          False
# 1                834           666              178          False
# 2                 10            88              155          False
# 3              49165          3933            21853           True
# 4                152           580             1473          False
# ...              ...           ...              ...            ...
# 4641            1109          2478            40866          False
# 4642            5463           629              217          False
# 4643            4020          1729            65978          False
# 4644             179           561               36          False
# 4645            3976          4558             9630          False
#
#                      date                                               text  \
# 0     2020-12-20 06:06:44  Same folks said daikon paste could treat a cyt...
# 1     2020-12-13 16:27:13  While the world has been on the wrong side of ...
# 2     2020-12-12 20:33:45  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3     2020-12-12 20:23:59  Facts are immutable, Senator, even when you're...
# 4     2020-12-12 20:17:19  Explain to me again why we need a vaccine @Bor...
# ...                   ...                                                ...
# 4641  2021-01-19 12:10:31  @AbbasTermezi @THLresearch @HNohynek Well, I t...
# 4642  2021-01-19 12:03:07  Second dose of the #PfizerBioNTech vaccine rol...
# 4643  2021-01-19 11:33:10  🔥MUST READ!!! #WakeUpAmerica #COVID19 #plandem...
# 4644  2021-01-19 11:30:29  This week APEX will introduce a brand new COVI...
# 4645  2021-01-19 11:16:25  @minnyshell I had #PfizerBioNTech vaccine, 2nd...
#
#                                                hashtags               source  \
# 0                                    ['PfizerBioNTech']  Twitter for Android
# 1                                                   NaN      Twitter Web App
# 2     ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...  Twitter for Android
# 3                                                   NaN      Twitter Web App
# 4        ['whereareallthesickpeople', 'PfizerBioNTech']   Twitter for iPhone
# ...                                                 ...                  ...
# 4641                                         ['Phase4']     Twitter for iPad
# 4642                    ['PfizerBioNTech', 'Andalucia']            TweetDeck
# 4643  ['WakeUpAmerica', 'COVID19', 'plandemic', 'vac...   Twitter for iPhone
# 4644                                                NaN      Twitter Web App
# 4645                                 ['PfizerBioNTech']      Twitter Web App
#
#       retweets  favorites  is_retweet
# 0            0          0       False
# 1            1          1       False
# 2            0          0       False
# 3          446       2129       False
# 4            0          0       False
# ...        ...        ...         ...
# 4641         1          1       False
# 4642         2          3       False
# 4643         1          1       False
# 4644         1          0       False
# 4645         2          4       False
#
# [4646 rows x 16 columns]

# %%
data.shape
# Out:
# (4646, 16)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4646, step=1)

# %%
data.dtypes
# Out:
# id                   int64
# user_name           object
# user_location       object
# user_description    object
# user_created        object
# user_followers       int64
# user_friends         int64
# user_favourites      int64
# user_verified         bool
# date                object
# text                object
# hashtags            object
# source              object
# retweets             int64
# favorites            int64
# is_retweet            bool
# dtype: object

# %%
data.count()
# Out:
# id                  4646
# user_name           4646
# user_location       3686
# user_description    4354
# user_created        4646
# user_followers      4646
# user_friends        4646
# user_favourites     4646
# user_verified       4646
# date                4646
# text                4646
# hashtags            3446
# source              4645
# retweets            4646
# favorites           4646
# is_retweet          4646
# dtype: int64

# %%
data['user_verified'].value_counts()
# Out:
# False    4156
# True      490
# Name: user_verified, dtype: int64

# %%
sns.countplot(x='user_verified',data=data)
# Out:
# <AxesSubplot:xlabel='user_verified', ylabel='count'>

# %%
 print('sources of tweeting')
data['source'].value_counts()
# Out:
# sources of tweeting
# Twitter for iPhone                 1647
# Twitter Web App                    1393
# Twitter for Android                1085
# TweetDeck                           256
# Twitter for iPad                    123
# Buffer                               39
# Instagram                            26
# Hootsuite Inc.                       16
# Nonli                                 6
# SocialFlow                            5
# LinkedIn                              5
# Microsoft Power Platform              5
# IFTTT                                 4
# 24liveblog                            4
# Twitter for Mac                       4
# Sendible                              4
# Falcon Social Media Management        2
# GT_Backend                            2
# Twitter Media Studio                  2
# Echobox                               2
# Paper.li                              2
# Publer                                1
# UberSocial for Android                1
# ThreadReaderApp                       1
# Sprout Social                         1
# EastMojo                              1
# WordPress.com                         1
# Twitter Media Studio - LiveCut        1
# Blog2Social APP                       1
# News Users                            1
# SocialNewsDesk                        1
# TweetCaster for Android               1
# Tweetbot for Mac                      1
# Socialbakers                          1
# Name: source, dtype: int64

# %%
df = data['user_verified'].value_counts().to_dict()
df['Verified'] = df.pop(True)
df['Not-Verified'] = df.pop(False)

plt.figure(figsize=(7,9))
plt.pie(x=df.values(), labels=df.keys(), autopct='%1.1f%%', shadow=True, startangle=0, explode = [0.1, 0])
plt.show()

# %%
from collections import Counter
df = Counter(data['source'].tolist()).most_common(5)
temp = pd.DataFrame(df, columns=['Source', 'Count'])

plt.figure(figsize=(7,7))
plt.pie(x=temp['Count'], labels=temp['Source'], autopct='%1.1f%%', shadow=True, startangle=0, explode = [0.1,0,0,0,0])
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.countplot(y='user_name', data=data, order=data['user_name'].value_counts().index[:15])
plt.xlabel('Number of Tweets', weight='bold')
plt.ylabel('user_name', weight='bold')
plt.show()

# %%
plt.figure(figsize=(8,10))
sns.countplot(y='user_location', data=data, order=data['user_location'].value_counts().index[:10])
plt.xlabel('Number of User', weight='bold')
plt.ylabel('Location', weight='bold')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.drop(columns=['id','is_retweet']).corr(), square=True, annot=True)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.countplot(y='hashtags', data=data, order=data['hashtags'].value_counts().index[:15])
plt.xlabel('Number of Hashtags', weight='bold')
plt.ylabel('Hashtags', weight='bold')
plt.show()

# %%
def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='Black',
        stopwords=stopwords,
        max_words=50,
        max_font_size=40, 
        scale=5,
        random_state=1
    ).generate(str(data))

    fig = plt.figure(1, figsize=(10,10))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

# %%
show_wordcloud(data['text'], title = 'Prevalent words in tweets')

# %%
show_wordcloud(data['hashtags'], title = 'Prevalent words in tweets')
